# %% [markdown]
# <a href="https://colab.research.google.com/github/Juscostajr/analise-de-dados-turma-2023/blob/main/Aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('carioca.csv')

# %%
df[['mandante','publico']].groupby('mandante').sum().plot.bar()
# Out:
# <Axes: xlabel='mandante'>

# %%
df.plot.pie(y='publico', labels=df['mandante'])
# Out:
# <Axes: ylabel='publico'>

# %%
df['publico'].describe()
# Out:
# count        7.000000
# mean     12336.857143
# std      24758.634133
# min        635.000000
# 25%       1036.500000
# 50%       1250.000000
# 75%       7200.000000
# max      68000.000000
# Name: publico, dtype: float64

# %%
df.boxplot('publico')
# Out:
# <Axes: >

# %%
titanic['age'].describe()
